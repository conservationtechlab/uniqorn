# %%
import pandas as pd

# %%
trainingdata = pd.read_csv("/home/kyra/Desktop/Data/Jaguar/train.csv")

# %%
trainingdata
# Out:
#       Unnamed: 0.2  Unnamed: 0  Unnamed: 0.1    X.1  \
# 0                0           0             1      1
# 1                1           1          3526   4027
# 2                2           2          3527   4028
# 3                3           3          3528   4029
# 4                4           4          3529   4030
# ...            ...         ...           ...    ...
# 1576          1576        1576         12564  14261
# 1577          1577        1577         12569  14267
# 1578          1578        1578         12570  14268
# 1579          1579        1579         12571  14269
# 1580          1580        1580         12596  14300
#
#                                                   Frame  CaptureID  SurveyID  \
# 0     S:/Camera Base MT/Images/1/AABP 13_20051007_12...        250         1
# 1     S:/Camera Base MT/Images/2/AABP 14_20060818_17...        601         2
# 2     S:/Camera Base MT/Images/2/AABP 14_20060904_19...        608         2
# 3     S:/Camera Base MT/Images/2/AABP 15_20060818_17...        601         2
# 4     S:/Camera Base MT/Images/2/AABP 15_20060818_17...        601         2
# ...                                                 ...        ...       ...
# 1576  S:/Camera Base MT/Images/7/E10_20091216_130218...       6067         7
# 1577  S:/Camera Base MT/Images/7/E12_20091216_130250...       6067         7
# 1578  S:/Camera Base MT/Images/7/E12_20100228_181010...       6160         7
# 1579  S:/Camera Base MT/Images/7/E12_20100228_181012...       6161         7
# 1580  S:/Camera Base MT/Images/7/E24_20091101_190112...       5035         7
#
#       StationID      Survey.Name  SpeciesID  ...     bbox4  \
# 0             9  Los Amigos 2005          2  ...  0.375791
# 1            30  Los Amigos 2006          2  ...  0.232320
# 2            30  Los Amigos 2006          2  ...  0.222395
# 3            30  Los Amigos 2006          2  ...  0.669003
# 4            30  Los Amigos 2006          2  ...  0.996549
# ...         ...              ...        ...  ...       ...
# 1576        231    Espinoza 2009          2  ...  0.275089
# 1577        231    Espinoza 2009          2  ...  0.996934
# 1578        231    Espinoza 2009          2  ...  0.355810
# 1579        231    Espinoza 2009          2  ...  0.317703
# 1580        218    Espinoza 2009          2  ...  0.409106
#
#                                              image_path crop_rel_path  \
# 0     S:/Camera Base MT/Images/1/AABP 13_20051007_12...           /1/
# 1     S:/Camera Base MT/Images/2/AABP 14_20060818_17...           /2/
# 2     S:/Camera Base MT/Images/2/AABP 14_20060904_19...           /2/
# 3     S:/Camera Base MT/Images/2/AABP 15_20060818_17...           /2/
# 4     S:/Camera Base MT/Images/2/AABP 15_20060818_17...           /2/
# ...                                                 ...           ...
# 1576  S:/Camera Base MT/Images/7/E10_20091216_130218...           /7/
# 1577  S:/Camera Base MT/Images/7/E12_20091216_130250...           /7/
# 1578  S:/Camera Base MT/Images/7/E12_20100228_181010...           /7/
# 1579  S:/Camera Base MT/Images/7/E12_20100228_181012...           /7/
# 1580  S:/Camera Base MT/Images/7/E24_20091101_190112...           /7/
#
#       max_conf                                          crop_path  UID  \
# 0     0.949430  S:/Jaguar Export/Crops/1/AABP 13_20051007_1205...    1
# 1     0.952257  S:/Jaguar Export/Crops/2/AABP 14_20060818_1730...    1
# 2     0.973084  S:/Jaguar Export/Crops/2/AABP 14_20060904_1937...    1
# 3     0.981198  S:/Jaguar Export/Crops/2/AABP 15_20060818_1730...    1
# 4     0.600471  S:/Jaguar Export/Crops/2/AABP 15_20060818_1730...    1
# ...        ...                                                ...  ...
# 1576  0.970055   S:/Jaguar Export/Crops/7/E10_20091216_130218.jpg  104
# 1577  0.983038   S:/Jaguar Export/Crops/7/E12_20091216_130250.jpg  104
# 1578  0.952535   S:/Jaguar Export/Crops/7/E12_20100228_181010.jpg  104
# 1579  0.907005   S:/Jaguar Export/Crops/7/E12_20100228_181012.jpg  104
# 1580  0.977290   S:/Jaguar Export/Crops/7/E24_20091101_190112.jpg  104
#
#                                              local_path  height width  \
# 0     /home/kyra/Desktop/Data/Jaguar/Images/1/AABP 1...    1228  1818
# 1     /home/kyra/Desktop/Data/Jaguar/Images/2/AABP 1...    1405  2007
# 2     /home/kyra/Desktop/Data/Jaguar/Images/2/AABP 1...    1405  2007
# 3     /home/kyra/Desktop/Data/Jaguar/Images/2/AABP 1...    1405  2007
# 4     /home/kyra/Desktop/Data/Jaguar/Images/2/AABP 1...    1405  2007
# ...                                                 ...     ...   ...
# 1576  /home/kyra/Desktop/Data/Jaguar/Images/7/E10_20...    1920  2560
# 1577  /home/kyra/Desktop/Data/Jaguar/Images/7/E12_20...    1920  2560
# 1578  /home/kyra/Desktop/Data/Jaguar/Images/7/E12_20...    1920  2560
# 1579  /home/kyra/Desktop/Data/Jaguar/Images/7/E12_20...    1920  2560
# 1580  /home/kyra/Desktop/Data/Jaguar/Images/7/E24_20...    1920  2560
#
#                                               mask_path
# 0     /home/kyra/Desktop/Data/Jaguar/Masked/1/AABP 1...
# 1     /home/kyra/Desktop/Data/Jaguar/Masked/2/AABP 1...
# 2     /home/kyra/Desktop/Data/Jaguar/Masked/2/AABP 1...
# 3     /home/kyra/Desktop/Data/Jaguar/Masked/2/AABP 1...
# 4     /home/kyra/Desktop/Data/Jaguar/Masked/2/AABP 1...
# ...                                                 ...
# 1576  /home/kyra/Desktop/Data/Jaguar/Masked/7/E10_20...
# 1577  /home/kyra/Desktop/Data/Jaguar/Masked/7/E12_20...
# 1578  /home/kyra/Desktop/Data/Jaguar/Masked/7/E12_20...
# 1579  /home/kyra/Desktop/Data/Jaguar/Masked/7/E12_20...
# 1580  /home/kyra/Desktop/Data/Jaguar/Masked/7/E24_20...
#
# [1581 rows x 48 columns]

# %%
from PIL import Image
import os
from tqdm import tqdm

# %%
for i, row in tqdm(trainingdata.iterrows()):
    path = row['mask_path']
    jpegpath = '/home/kyra/Desktop/Data/Jaguar/Masked/24/' + os.path.splitext(os.path.basename(path))[0] + '.jpg'
    

    im1 = Image.open(path)
    rgb_im = im1.convert('RGB')
    rgb_im.save(jpegpath)
# Out:
# 1581it [00:07, 201.25it/s]

# %%
x = os.listdir('/home/kyra/Desktop/Data/Jaguar/Masked/24/')

# %%
x
# Out:
# ['SDZG  189_20140818_121113_001.jpg',
#  'SDZG  218_20140724_163903.jpg',
#  'SDZG  148_20140815_083851.jpg',
#  'SDZG  147_20140829_064718_002.jpg',
#  'SDZG  125_20140811_221951.jpg',
#  'SDZG 49_20140725_091254.jpg',
#  'Areas 55_20071103_0527.jpg',
#  'Areas16_20091110_235900.jpg',
#  'SDZG  78_20140718_070647.jpg',
#  'SDZG 222_20140908_185627.jpg',
#  'SDZG  141_20140830_073618_001.jpg',
#  'Areas51_20091021_173352.jpg',
#  'SDZG 90_20140901_075616.jpg',
#  'SDZG 92_20140711_190044_001.jpg',
#  'SDZG 196_20140903_193334.jpg',
#  'AABP 33_20071008_0505.jpg',
#  'SDZG  205_20141004_200411.jpg',
#  'SDZG 222_20140627_071959_001.jpg',
#  'Areas32_20091224_063400.jpg',
#  'SDZG  231_20140628_182026_001.jpg',
#  'SDZG  142_20140905_143906.jpg',
#  'SDZG  10_20140726_085246.jpg',
#  'SDZG  126_20141008_200645.jpg',
#  'SDZG  160_20141004_054605_001.jpg',
#  'SDZG  12_20140727_023751.jpg',
#  'SDZG  226_20140720_075643_001.jpg',
#  'SDZG  17_20140821_211601.jpg',
#  'SDZG  87_20140817_180156.jpg',
#  'SDZG  17_20140811_221949.jpg',
#  'SDZG  160_20140922_074725.jpg',
#  'SDZG 177_20140802_071112.jpg',
#  'SDZG  117_20140810_051605.jpg',
#  'SDZG  117_20140821_184352_001.jpg',
#  'SDZG 223_20140901_034538.jpg',
#  'SDZG  122_20141015_235323.jpg',
#  'SDZG  174_20141014_003826.jpg',
#  'AABP36_20100208_183600.jpg',
#  'SDZG  125_20140810_075341.jpg',
#  'SDZG  99_20141007_062355.jpg',
#  'SDZG  231_20140915_044216.jpg',
#  ...]

# %%
import deeplabcut
# Out:
# 2023-08-21 15:34:14.661745: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-08-21 15:34:14.663164: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-21 15:34:14.693419: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-21 15:34:14.694001: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-21 15:34:15.266382: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading DLC 2.3.5...
# DLC loaded in light mode; you cannot use any GUI (labeling, relabeling and standalone GUI)
# /home/kyra/anaconda3/envs/reid/lib/python3.10/site-packages/qtpy/__init__.py:267: RuntimeWarning: Selected binding "pyside6" could not be found, using "pyqt5"
#   warnings.warn('Selected binding "{}" could not be found, '

# %%
# Adapted from https://huggingface.co/spaces/hlydecker/MegaDetector_v5 
# Adapted from https://huggingface.co/spaces/sofmi/MegaDetector_DLClive/blob/main/app.py
# Adapted from https://huggingface.co/spaces/Neslihan/megadetector_dlcmodels/blob/main/app.py 
# Adapted from  https://huggingface.co/spaces/DeepLabCut/MegaDetector_DeepLabCut

import os
import yaml
import numpy as np
from matplotlib import cm
import gradio as gr
import deeplabcut
import dlclibrary
import dlclive
import transformers

from PIL import Image, ImageColor, ImageFont, ImageDraw 
import requests

from viz_utils import save_results_as_json, draw_keypoints_on_image, draw_bbox_w_text, save_results_only_dlc
from detection_utils import predict_md, crop_animal_detections
from dlc_utils import predict_dlc
from ui_utils import gradio_inputs_for_MD_DLC, gradio_outputs_for_MD_DLC, gradio_description_and_examples

from deeplabcut.utils import auxiliaryfunctions
from dlclibrary.dlcmodelzoo.modelzoo_download import (
    download_huggingface_model,
    MODELOPTIONS,
)
from dlclive import DLCLive, Processor


# TESTING (passes) download the SuperAnimal models:
#model = 'superanimal_topviewmouse'
#train_dir = 'DLC_models/sa-tvm'
#download_huggingface_model(model, train_dir)

# grab demo data cooco cat:
url = "http://images.cocodataset.org/val2017/000000039769.jpg"
image = Image.open(requests.get(url, stream=True).raw)

# megadetector and dlc model look up
MD_models_dict = {'md_v5a': "MD_models/md_v5a.0.0.pt", # 
                  'md_v5b': "MD_models/md_v5b.0.0.pt"}

# DLC models target  dirs
DLC_models_dict = {'superanimal_topviewmouse': "DLC_models/sa-tvm",
                   'superanimal_quadruped': "DLC_models/sa-q",
                    'full_human': "DLC_models/DLC_human_dancing/"}


#####################################################
def predict_pipeline(img_input,
                     mega_model_input,
                     dlc_model_input_str,
                     flag_dlc_only,
                     flag_show_str_labels,
                     bbox_likelihood_th,
                     kpts_likelihood_th,
                     font_style,
                     font_size,
                     keypt_color,
                     marker_size,
                     ):

    if not flag_dlc_only:
        ############################################################                                               
        # ### Run Megadetector
        md_results = predict_md(img_input, 
                                MD_models_dict[mega_model_input], #mega_model_input,
                                size=640) #Image.fromarray(results.imgs[0])

        ################################################################
        # Obtain animal crops for bboxes with confidence above th
        list_crops = crop_animal_detections(img_input,
                                            md_results,
                                            bbox_likelihood_th)

        ############################################################

    ## Get DLC model and label map  
    
    # If model is found: do not download (previous execution is likely within same day)
    # TODO: can we ask the user whether to reload dlc model if a directory is found?
    if os.path.isdir(DLC_models_dict[dlc_model_input_str]) and \
        len(os.listdir(DLC_models_dict[dlc_model_input_str])) > 0:
        path_to_DLCmodel = DLC_models_dict[dlc_model_input_str]
    else:
        path_to_DLCmodel = DLC_models_dict[dlc_model_input_str]
        download_huggingface_model(dlc_model_input_str, path_to_DLCmodel)

    # extract map label ids to strings
    pose_cfg_path = os.path.join(DLC_models_dict[dlc_model_input_str],
                                 'pose_cfg.yaml')
    with open(pose_cfg_path, "r") as stream:
        pose_cfg_dict = yaml.safe_load(stream) 
    map_label_id_to_str = dict([(k,v) for k,v in zip([el[0] for el in pose_cfg_dict['all_joints']],  # pose_cfg_dict['all_joints'] is a list of one-element lists,
                                                     pose_cfg_dict['all_joints_names'])])


##############################################################
    # Run DLC and visualize results
    dlc_proc = Processor() #TODO: update deeplabcut.video_inference_superanimal() once merged

    # if required: ignore MD crops and run DLC on full image [mostly for testing]
    if flag_dlc_only:
        # compute kpts on input img
        list_kpts_per_crop = predict_dlc([np.asarray(img_input)],
                                         kpts_likelihood_th,
                                         path_to_DLCmodel,
                                         dlc_proc)
        # draw kpts on input img #fix!
        draw_keypoints_on_image(img_input,
                                list_kpts_per_crop[0], # a numpy array with shape [num_keypoints, 2].
                                map_label_id_to_str,
                                flag_show_str_labels,
                                use_normalized_coordinates=False,
                                font_style=font_style,
                                font_size=font_size,
                                keypt_color=keypt_color,
                                marker_size=marker_size)

        donw_file = save_results_only_dlc(list_kpts_per_crop[0], map_label_id_to_str,dlc_model_input_str)

        return img_input, donw_file

    else:
        # Compute kpts for each crop
        list_kpts_per_crop = predict_dlc(list_crops,
                                         kpts_likelihood_th,
                                         path_to_DLCmodel,
                                         dlc_proc)
        
        # resize input image to match megadetector output
        img_background = img_input.resize((md_results.ims[0].shape[1],
                                           md_results.ims[0].shape[0]))
        
        # draw keypoints on each crop and paste to background img
        for ic, (np_crop, kpts_crop) in enumerate(zip(list_crops,
                                                      list_kpts_per_crop)):

            img_crop = Image.fromarray(np_crop)

            # Draw keypts on crop
            draw_keypoints_on_image(img_crop,
                                    kpts_crop, # a numpy array with shape [num_keypoints, 2].
                                    map_label_id_to_str,
                                    flag_show_str_labels,
                                    use_normalized_coordinates=False,  # if True, then I should use md_results.xyxyn for list_kpts_crop
                                    font_style=font_style,
                                    font_size=font_size,
                                    keypt_color=keypt_color,
                                    marker_size=marker_size)

            # Paste crop in original image
            img_background.paste(img_crop, 
                                 box = tuple([int(t) for t in md_results.xyxy[0][ic,:2]]))

            # Plot bbox
            bb_per_animal = md_results.xyxy[0].tolist()[ic]
            pred = md_results.xyxy[0].tolist()[ic][4]
            if bbox_likelihood_th < pred:
                draw_bbox_w_text(img_background, 
                                    bb_per_animal,
                                    font_size=font_size)  # TODO: add selectable color for bbox?

            
        # Save detection results as json
        download_file  = save_results_as_json(md_results,list_kpts_per_crop,map_label_id_to_str, bbox_likelihood_th,dlc_model_input_str,mega_model_input)         

        return img_background, download_file



#########################################################
# Define user interface and launch
inputs = gradio_inputs_for_MD_DLC(list(MD_models_dict.keys()),
                                  list(DLC_models_dict.keys()))
outputs = gradio_outputs_for_MD_DLC()                                    
[gr_title, 
 gr_description, 
 examples] = gradio_description_and_examples()

# launch
demo = gr.Interface(predict_pipeline, 
                    inputs=inputs,
                    outputs=outputs, 
                    title=gr_title, 
                    description=gr_description,
                    examples=examples,
                    theme="huggingface")

demo.launch(enable_queue=True, share=True)
# Out:
# Loading.... superanimal_quadruped
# Downloading (…)n-0_shuffle-1.tar.gz:   0%|          | 0.00/294M [00:00<?, ?B/s]
# /home/kyra/anaconda3/envs/reid/lib/python3.10/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 5
#       2 superanimal_name = 'superanimal_quadruped'
#       3 scale_list = range(200, 600, 50)  # image height pixel size range and increment
# ----> 5 deeplabcut.video_inference_superanimal([video_path], superanimal_name, scale_list=scale_list)
#
# File ~/anaconda3/envs/reid/lib/python3.10/site-packages/deeplabcut/pose_estimation_tensorflow/predict_supermodel.py:102, in video_inference_superanimal(videos, superanimal_name, scale_list, videotype, video_adapt, plot_trajectories, pcutoff, adapt_iterations, pseudo_threshold, trim_ends)
#      94 adapter = SpatiotemporalAdaptation(
#      95     video,
#      96     superanimal_name,
#    (...)
#      99     scale_list=scale_list,
#     100 )
#     101 if not video_adapt:
# --> 102     adapter.before_adapt_inference(make_video=True,
#     103                                    pcutoff=pcutoff,
#     104                                    plot_trajectories = plot_trajectories)
#     105 else:
#     106     adapter.before_adapt_inference(make_video=False)
#
# File ~/anaconda3/envs/reid/lib/python3.10/site-packages/deeplabcut/modelzoo/api/spatiotemporal_adapt.py:111, in SpatiotemporalAdaptation.before_adapt_inference(self, make_video, **kwargs)
#     102     _, datafiles = superanimal_inference.video_inference(
#     103         [self.video_path],
#     104         self.supermodel_name,
#    (...)
#     108         customized_test_config=self.customized_pose_config,
#     109     )
#     110 else:
# --> 111     self.init_weights, datafiles = superanimal_inference.video_inference(
#     112         [self.video_path],
#     113         self.supermodel_name,
#     114         videotype=self.videotype,
#     115         scale_list=self.scale_list,
#     116         customized_test_config=self.customized_pose_config,
#     117     )
#     118 if kwargs.pop('plot_trajectories', True):
#     119     _plot_trajectories(datafiles[0])
#
# File ~/anaconda3/envs/reid/lib/python3.10/site-packages/deeplabcut/modelzoo/api/superanimal_inference.py:320, in video_inference(videos, superanimal_name, scale_list, videotype, destfolder, batchsize, robust_nframes, allow_growth, init_weights, customized_test_config)
#     317 test_cfg["num_outputs"] = 1
#     318 test_cfg["batch_size"] = batchsize
# --> 320 sess, inputs, outputs = single_predict.setup_pose_prediction(
#     321     test_cfg, allow_growth=allow_growth
#     322 )
#     323 DLCscorer = "DLC_" + Path(test_cfg["init_weights"]).stem
#     324 videos = auxiliaryfunctions.get_list_of_videos(videos, videotype)
#
# File ~/anaconda3/envs/reid/lib/python3.10/site-packages/deeplabcut/pose_estimation_tensorflow/core/predict.py:26, in setup_pose_prediction(cfg, allow_growth, collect_extra)
#      22 tf.compat.v1.reset_default_graph()
#      23 inputs = tf.compat.v1.placeholder(
#      24     tf.float32, shape=[cfg["batch_size"], None, None, 3]
#      25 )
# ---> 26 net_heads = PoseNetFactory.create(cfg).test(inputs)
#      27 extra_dict = {}
#      28 outputs = [net_heads["part_prob"]]
#
# File ~/anaconda3/envs/reid/lib/python3.10/site-packages/deeplabcut/pose_estimation_tensorflow/nnets/base.py:85, in BasePoseNet.test(self, inputs)
#      84 def test(self, inputs):
# ---> 85     heads = self.get_net(inputs)
#      86     return self.add_inference_layers(heads)
#
# File ~/anaconda3/envs/reid/lib/python3.10/site-packages/deeplabcut/pose_estimation_tensorflow/nnets/resnet.py:79, in PoseResnet.get_net(self, inputs)
#      78 def get_net(self, inputs):
# ---> 79     net, end_points = self.extract_features(inputs)
#      80     return self.prediction_layers(net, end_points)
#
# File ~/anaconda3/envs/reid/lib/python3.10/site-packages/deeplabcut/pose_estimation_tensorflow/nnets/resnet.py:41, in PoseResnet.extract_features(self, inputs)
#      39 im_centered = self.center_inputs(inputs)
#      40 with slim.arg_scope(resnet_v1.resnet_arg_scope()):
# ---> 41     net, end_points = net_fun(
#      42         im_centered,
#      43         global_pool=False,
#      44         output_stride=16,
#      45         is_training=False,
#      46     )
#      47 return net, end_points
#
# File ~/anaconda3/envs/reid/lib/python3.10/site-packages/tf_slim/nets/resnet_v1.py:270, in resnet_v1_50(inputs, num_classes, is_training, global_pool, output_stride, reuse, scope)
#     263 """ResNet-50 model of [1]. See resnet_v1() for arg and return description."""
#     264 blocks = [
#     265     resnet_v1_block('block1', base_depth=64, num_units=3, stride=2),
#     266     resnet_v1_block('block2', base_depth=128, num_units=4, stride=2),
#     267     resnet_v1_block('block3', base_depth=256, num_units=6, stride=2),
#     268     resnet_v1_block('block4', base_depth=512, num_units=3, stride=1),
#     269 ]
# --> 270 return resnet_v1(
#     271     inputs,
#     272     blocks,
#     273     num_classes,
#     274     is_training,
#     275     global_pool,
#     276     output_stride,
#     277     include_root_block=True,
#     278     reuse=reuse,
#     279     scope=scope)
#
# File ~/anaconda3/envs/reid/lib/python3.10/site-packages/tf_slim/nets/resnet_v1.py:210, in resnet_v1(inputs, blocks, num_classes, is_training, global_pool, output_stride, include_root_block, reuse, scope)
#     208       raise ValueError('The output_stride needs to be a multiple of 4.')
#     209     output_stride /= 4
# --> 210   net = resnet_utils.conv2d_same(net, 64, 7, stride=2, scope='conv1')
#     211   net = layers_lib.max_pool2d(net, [3, 3], stride=2, scope='pool1')
#     212 net = resnet_utils.stack_blocks_dense(net, blocks, output_stride)
#
# File ~/anaconda3/envs/reid/lib/python3.10/site-packages/tf_slim/nets/resnet_utils.py:143, in conv2d_same(inputs, num_outputs, kernel_size, stride, rate, scope)
#     140 pad_end = pad_total - pad_beg
#     141 inputs = array_ops.pad(
#     142     inputs, [[0, 0], [pad_beg, pad_end], [pad_beg, pad_end], [0, 0]])
# --> 143 return layers_lib.conv2d(
#     144     inputs,
#     145     num_outputs,
#     146     kernel_size,
#     147     stride=stride,
#     148     rate=rate,
#     149     padding='VALID',
#     150     scope=scope)
#
# File ~/anaconda3/envs/reid/lib/python3.10/site-packages/tf_slim/ops/arg_scope.py:184, in add_arg_scope.<locals>.func_with_args(*args, **kwargs)
#     182   current_args = current_scope[key_func].copy()
#     183   current_args.update(kwargs)
# --> 184 return func(*args, **current_args)
#
# File ~/anaconda3/envs/reid/lib/python3.10/site-packages/tf_slim/layers/layers.py:1171, in convolution2d(inputs, num_outputs, kernel_size, stride, padding, data_format, rate, activation_fn, normalizer_fn, normalizer_params, weights_initializer, weights_regularizer, biases_initializer, biases_regularizer, reuse, variables_collections, outputs_collections, trainable, scope)
#    1151 @add_arg_scope
#    1152 def convolution2d(inputs,
#    1153                   num_outputs,
#    (...)
#    1169                   trainable=True,
#    1170                   scope=None):
# -> 1171   return convolution(
#    1172       inputs,
#    1173       num_outputs,
#    1174       kernel_size,
#    1175       stride,
#    1176       padding,
#    1177       data_format,
#    1178       rate,
#    1179       activation_fn,
#    1180       normalizer_fn,
#    1181       normalizer_params,
#    1182       weights_initializer,
#    1183       weights_regularizer,
#    1184       biases_initializer,
#    1185       biases_regularizer,
#    1186       reuse,
#    1187       variables_collections,
#    1188       outputs_collections,
#    1189       trainable,
#    1190       scope,
#    1191       conv_dims=2)
#
# File ~/anaconda3/envs/reid/lib/python3.10/site-packages/tf_slim/ops/arg_scope.py:184, in add_arg_scope.<locals>.func_with_args(*args, **kwargs)
#     182   current_args = current_scope[key_func].copy()
#     183   current_args.update(kwargs)
# --> 184 return func(*args, **current_args)
#
# File ~/anaconda3/envs/reid/lib/python3.10/site-packages/tf_slim/layers/layers.py:1098, in convolution(inputs, num_outputs, kernel_size, stride, padding, data_format, rate, activation_fn, normalizer_fn, normalizer_params, weights_initializer, weights_regularizer, biases_initializer, biases_regularizer, reuse, variables_collections, outputs_collections, trainable, scope, conv_dims)
#    1096 if normalizer_fn is not None:
#    1097   normalizer_params = normalizer_params or {}
# -> 1098   outputs = normalizer_fn(outputs, **normalizer_params)
#    1100 if activation_fn is not None:
#    1101   outputs = activation_fn(outputs)
#
# File ~/anaconda3/envs/reid/lib/python3.10/site-packages/tf_slim/ops/arg_scope.py:184, in add_arg_scope.<locals>.func_with_args(*args, **kwargs)
#     182   current_args = current_scope[key_func].copy()
#     183   current_args.update(kwargs)
# --> 184 return func(*args, **current_args)
#
# File ~/anaconda3/envs/reid/lib/python3.10/site-packages/tf_slim/layers/layers.py:663, in batch_norm(inputs, decay, center, scale, epsilon, activation_fn, param_initializers, param_regularizers, updates_collections, is_training, reuse, variables_collections, outputs_collections, trainable, batch_weights, fused, data_format, zero_debias_moving_mean, scope, renorm, renorm_clipping, renorm_decay, adjustment)
#     661 beta_regularizer = param_regularizers.get('beta')
#     662 gamma_regularizer = param_regularizers.get('gamma')
# --> 663 layer = normalization_layers.BatchNormalization(
#     664     axis=axis,
#     665     momentum=decay,
#     666     epsilon=epsilon,
#     667     center=center,
#     668     scale=scale,
#     669     beta_initializer=beta_initializer,
#     670     gamma_initializer=gamma_initializer,
#     671     moving_mean_initializer=moving_mean_initializer,
#     672     moving_variance_initializer=moving_variance_initializer,
#     673     beta_regularizer=beta_regularizer,
#     674     gamma_regularizer=gamma_regularizer,
#     675     trainable=trainable,
#     676     renorm=renorm,
#     677     renorm_clipping=renorm_clipping,
#     678     renorm_momentum=renorm_decay,
#     679     adjustment=adjustment,
#     680     name=sc.name,
#     681     _scope=sc,
#     682     _reuse=reuse,
#     683     fused=fused)
#     684 outputs = layer.apply(inputs, training=is_training)
#     686 # Add variables to collections.
#
# File ~/anaconda3/envs/reid/lib/python3.10/site-packages/tensorflow/python/layers/normalization.py:30, in __getattr__(name)
#      28 def __getattr__(name):
#      29   if name in ['BatchNormalization', 'BatchNorm']:
# ---> 30     return normalization.BatchNormalization
#      31   elif name in ['batch_normalization', 'batch_norm']:
#      32     return normalization.batch_normalization
#
# File ~/anaconda3/envs/reid/lib/python3.10/site-packages/tensorflow/python/util/lazy_loader.py:58, in LazyLoader.__getattr__(self, item)
#      57 def __getattr__(self, item):
# ---> 58   module = self._load()
#      59   return getattr(module, item)
#
# File ~/anaconda3/envs/reid/lib/python3.10/site-packages/tensorflow/python/util/lazy_loader.py:41, in LazyLoader._load(self)
#      39 """Load the module and insert it into the parent's globals."""
#      40 # Import the target module and insert it into the parent's namespace
# ---> 41 module = importlib.import_module(self.__name__)
#      42 self._parent_module_globals[self._local_name] = module
#      44 # Emit a warning if one was specified
#
# File ~/anaconda3/envs/reid/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/anaconda3/envs/reid/lib/python3.10/site-packages/keras/legacy_tf_layers/normalization.py:25
#      21 import warnings
#      23 import tensorflow.compat.v2 as tf
# ---> 25 from keras.layers.normalization import batch_normalization_v1
#      26 from keras.legacy_tf_layers import base
#      28 # isort: off
#
# File ~/anaconda3/envs/reid/lib/python3.10/site-packages/keras/layers/normalization/batch_normalization_v1.py:18
#       1 # Copyright 2015 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Batch Normalization V1 layer."""
# ---> 18 from keras.layers.normalization import batch_normalization
#      20 # isort: off
#      21 from tensorflow.python.util.tf_export import keras_export
#
# File ~/anaconda3/envs/reid/lib/python3.10/site-packages/keras/layers/normalization/batch_normalization.py:23
#      21 from keras import initializers
#      22 from keras import regularizers
# ---> 23 from keras.dtensor import utils
#      24 from keras.engine.base_layer import Layer
#      25 from keras.engine.input_spec import InputSpec
#
# File ~/anaconda3/envs/reid/lib/python3.10/site-packages/keras/dtensor/utils.py:21
#      17 import inspect
#      19 import tensorflow.compat.v2 as tf
# ---> 21 from keras.dtensor import dtensor_api as dtensor
#      23 # All the variable names in the default keras layers. We will use those to map
#      24 # against the args in the __init__ method to find corresponding layout args.
#      25 # See allow_layout() for more details.
#      26 KERAS_VARIABLE_NAMES = [
#      27     "alpha",
#      28     "beta",
#    (...)
#      37     "recurrent",
#      38 ]
#
# ImportError: cannot import name 'dtensor_api' from 'keras.dtensor' (/home/kyra/anaconda3/envs/reid/lib/python3.10/site-packages/keras/dtensor/__init__.py)

# %%
deeplabcut.analyze_time_lapse_frames(config,directory,frametype='.png',shuffle=1,
                trainingsetindex=0,gputouse=None,save_as_csv=False,rgb=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 eeplabcut.analyze_time_lapse_frames(config,directory,frametype='.png',shuffle=1,
#       2                 trainingsetindex=0,gputouse=None,save_as_csv=False,rgb=True)
#
# NameError: name 'eeplabcut' is not defined

# %%
configpath = deeplabcut.create_new_project('Viewpoint', 
                              'Kyra Swanson', 
                              [], 
                              working_directory='/home/kyra/Desktop/Data/Jaguar/', 
                              copy_videos=False, multianimal=False)
# Out:
# Created "/home/kyra/Desktop/Data/Jaguar/Viewpoint-Kyra Swanson-2023-08-21/videos"
# Created "/home/kyra/Desktop/Data/Jaguar/Viewpoint-Kyra Swanson-2023-08-21/labeled-data"
# Created "/home/kyra/Desktop/Data/Jaguar/Viewpoint-Kyra Swanson-2023-08-21/training-datasets"
# Created "/home/kyra/Desktop/Data/Jaguar/Viewpoint-Kyra Swanson-2023-08-21/dlc-models"
# Attempting to create a symbolic link of the video ...

# %%
configpath
# Out:
# 'nothingcreated'

# %%
deeplabcut.extract_frames(config_path, mode='automatic/manual', algo='uniform/kmeans', userfeedback=False, crop=True/False)
